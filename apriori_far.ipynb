# %%
#Associação

#Bibliotecas
# !pip install --upgrade apyori
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori

#Tabela pandas
store_data = pd.read_excel('remedios.xlsx', header=None)
print(store_data)
records = []

coluna = store_data.shape[1]
coluna = coluna + 1

for i in store_data.itertuples():
    incluirlista = []
    incluirlista.append(str(i[1]))
    for j in range(2,coluna):
        if (str(i[j])!='nan'):
            incluirlista.append(str(i[j]))    
    records.append(incluirlista)

#Fim tabela pandas
print()
for i in records:
    print(i)

association_rules = apriori(records, min_support = 0.1, min_confidence = 0.5, min_lift = 1.3)
association_results = list(association_rules)

contador = 0
for item in association_results:
    print()
    #print(item)
    suporte = item[1]
    for x in item[2]:
        origem = ''
        destino = ''

        #ORIGEM
    for i in x[0]:
        if (origem == ''):
            origem = i
        else:
            origem = origem + ', ' + i
        
        #DESTINO
    for i in x[1]:
        if (destino == ''):
            destino = i
        else:
            destino = destino + ', ' + i

    if (origem != '' and destino != ''):
        print(f'Clientes que compraram: {origem} --> {destino}')
        contador += 1
        print(f"Support: {suporte:.2f}")
        print(f'Confidence: {x[2]:.2f}')
        print(f'Lift: {x[3]:.2f}')
        print('='*47)
print()
print(f'RESULTADOS: {contador}')
# Out:
# Requirement already up-to-date: apyori in /usr/local/lib/python3.6/dist-packages (1.1.2)
#               0           1           2
# 0      Dipirona   Cimegripe         NaN
# 1     Omeprazol    Dipirona         NaN
# 2      Rivotril      Exudos   Omeprazol
# 3      Rivotril      Exudos         NaN
# 4     Omeprazol   Novalgina         NaN
# 5      Rivotril   Novalgina   Omeprazol
# 6     Cimegripe    Dipirona    Dipirona
# 7        Exudos         NaN         NaN
# 8     Passflora  Sintocalmy      Exudos
# 9    Sintocalmy      Exudos         NaN
# 10   Simeticona   Omeprazol         NaN
# 11   Clonazepan    Rivotril  Sintocalmy
# 12  Imunoglucan   Cimegripe    Dipirona
# 13     Divertil    Dipirona         NaN
# 14    Embelezol      Exudos         NaN
#
# ['Dipirona', 'Cimegripe']
# ['Omeprazol', 'Dipirona']
# ['Rivotril', 'Exudos', 'Omeprazol']
# ['Rivotril', 'Exudos']
# ['Omeprazol', 'Novalgina']
# ['Rivotril', 'Novalgina', 'Omeprazol']
# ['Cimegripe', 'Dipirona', 'Dipirona']
# ['Exudos']
# ['Passflora', 'Sintocalmy', 'Exudos']
# ['Sintocalmy', 'Exudos']
# ['Simeticona', 'Omeprazol']
# ['Clonazepan', 'Rivotril', 'Sintocalmy']
# ['Imunoglucan', 'Cimegripe', 'Dipirona']
# ['Divertil', 'Dipirona']
# ['Embelezol', 'Exudos']
#
# Clientes que compraram: Dipirona --> Cimegripe
# Support: 0.20
# Confidence: 0.60
# Lift: 3.00
# ===============================================
#
# Clientes que compraram: Sintocalmy --> Exudos
# Support: 0.13
# Confidence: 0.67
# Lift: 1.67
# ===============================================
#
# Clientes que compraram: Novalgina --> Omeprazol
# Support: 0.13
# Confidence: 1.00
# Lift: 3.00
# ===============================================
#
# Clientes que compraram: Rivotril --> Omeprazol
# Support: 0.13
# Confidence: 0.50
# Lift: 1.50
# ===============================================
#
# RESULTADOS: 4
